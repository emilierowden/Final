# %%
import pandas as pd
import seaborn as sns
heart = pd.read_csv("/content/drive/MyDrive/Heart_disease_Final.csv")
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0

# %%
sns.displot(heart, x="trestbps", hue="sex", kind="kde", fill= True)

# %%
# get correlations
heart_corr = heart.corr()
plt.figure()
plt.imshow(heart_corr, cmap='hot', interpolation='nearest')
ax = plt.gca()

plt.xticks(rotation=90)
ax.set_xticks(range(len(heart_corr.columns)))
ax.set_xticklabels(heart_corr.columns)

ax.set_yticks(range(len(heart_corr.columns)))
ax.set_yticklabels(heart_corr.columns)
plt.show()

# %%
import seaborn as sb
sb.heatmap(heart_corr)

# %%
sns.boxplot(data=heart, x='cp', y="thalach")
plt.xlabel("Chest Pain Type")
plt.ylabel("Maximum Heart Rate")
# Out:
# Text(0, 0.5, 'Maximum Heart Rate')

# %%
sns.kdeplot(data=heart, x="chol", hue="fbs")
plt.xlabel("Cholesterol")
# Out:
# Text(0.5, 0, 'Cholesterol')
